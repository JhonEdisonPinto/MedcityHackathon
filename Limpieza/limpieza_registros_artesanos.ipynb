# %%
import pandas as pd

df_reg_artesanos = pd.read_csv(r"C:\Users\violeta\Documents\GitHub\MedcityHackathon\Database\registro_artesano_y_producto_formado_y_cualificados_en_diseno.csv", encoding="utf-8", sep =",")

# %%
df_reg_artesanos.head()
# Out:
#    edad       sexo cabeza_de_hogar caracterizacion_ciudadano  \
# 0  63.0  masculino              si               emprendedor
# 1  56.0  masculino              no               emprendedor
# 2  74.0  masculino              si               emprendedor
# 3  54.0   femenino              si               emprendedor
# 4  50.0   femenino              si               emprendedor
#
#   tipo_de_emprendimiento idea_de_negocio  estrato    barrio_vereda_ciudadano  \
# 0              artesanal     emprendedor      2.0                    robledo
# 1              artesanal     emprendedor      3.0                    bombona
# 2              artesanal     emprendedor      3.0                   guayabal
# 3              artesanal     emprendedor      4.0  america - santa monica #2
# 4              artesanal     emprendedor      4.0  america - santa monica #2
#
#   comuna_ciudadano   zona_ciudadano  fecha_de_beneficio_dia  \
# 0                7   nor-occidental                      15
# ...

# %%
df_reg_artesanos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   edad                       194 non-null    float64
#  1   sexo                       199 non-null    str
#  2   cabeza_de_hogar            180 non-null    str
#  3   caracterizacion_ciudadano  179 non-null    str
#  4   tipo_de_emprendimiento     176 non-null    str
#  5   idea_de_negocio            194 non-null    str
#  6   estrato                    179 non-null    float64
#  7   barrio_vereda_ciudadano    197 non-null    str
#  8   comuna_ciudadano           197 non-null    str
#  9   zona_ciudadano             197 non-null    str
#  10  fecha_de_beneficio_dia     199 non-null    int64
#  11  fecha_de_beneficio_mes     199 non-null    int64
#  12  fecha_de_beneficio_año     199 non-null    float64
# dtypes: float64(3), int64(2), str(8)
# memory usage: 20.3 KB

# %%
# Eliminar columnas cabeza_de_hogar, caracterizacion_ciudadano,estrato, fecha_de_beneficio_dia, fecha_de_beneficio_mes y fecha_de_beneficio_año
df_reg_artesanos.drop(columns=["cabeza_de_hogar", "caracterizacion_ciudadano", "estrato", "fecha_de_beneficio_dia", "fecha_de_beneficio_mes", "fecha_de_beneficio_año"], inplace=True)

# %%
df_reg_artesanos.head(20)
# Out:
#     edad       sexo tipo_de_emprendimiento idea_de_negocio  \
# 0   63.0  masculino              artesanal     emprendedor
# 1   56.0  masculino              artesanal     emprendedor
# 2   74.0  masculino              artesanal     emprendedor
# 3   54.0   femenino              artesanal     emprendedor
# 4   50.0   femenino              artesanal     emprendedor
# 5   52.0   femenino              artesanal     emprendedor
# 6   27.0   femenino              artesanal     emprendedor
# 7   61.0  masculino              artesanal     emprendedor
# 8   43.0   femenino              artesanal     emprendedor
# 9   39.0   femenino              artesanal     emprendedor
# 10  44.0  masculino              artesanal     emprendedor
# 11  39.0   femenino              artesanal     emprendedor
# 12  59.0  masculino              artesanal     emprendedor
# 13  53.0   femenino              artesanal     emprendedor
# 14  41.0   femenino              artesanal     emprendedor
# ...

# %%
df_reg_artesanos.to_csv(r"C:\Users\violeta\Documents\GitHub\MedcityHackathon\Database\registro_artesano_y_producto_formado_y_cualificados_en_diseno.csv", index=False, encoding="utf-8", sep =",")
