# %%
import pandas as pd

df_segmentacion = pd.read_csv(r"C:\Users\violeta\Documents\GitHub\MedcityHackathon\Database\segmentacion_de_usuarios.csv", encoding="utf-8", sep =",")

# %%
df_segmentacion.head()
# Out:
#                                   Sedes  Autenticación_Correo  \
# 0         Aeroparque Juan Pablo Segundo                  6762
# 1  Ampliación 1 Estación Caribe (Norte)                  6776
# 2    Ampliación 2 Estación Caribe (Sur)                  6044
# 3           Ampliación Estación Estadio                 19760
# 4                   Ampliación La Honda                  9555
#
#    Autenticación_Facebook  Autenticación_Googleplus  Autenticación_Linkedin  \
# 0                     450                        51                       0
# 1                     200                         5                       0
# 2                     225                        20                       0
# 3                     768                        17                       0
# 4                     424                        15                       0
#
#    Autenticación_Twitter  Rango_edad_desconocido  Rango_edad_De_14_a_17_Años  \
# ...

# %%
df_segmentacion.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2650 entries, 0 to 2649
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sedes                                      2650 non-null   str
#  1   Autenticación_Correo                       2650 non-null   int64
#  2   Autenticación_Facebook                     2650 non-null   int64
#  3   Autenticación_Googleplus                   2650 non-null   int64
#  4   Autenticación_Linkedin                     2650 non-null   int64
#  5   Autenticación_Twitter                      2650 non-null   int64
#  6   Rango_edad_desconocido                     2650 non-null   int64
#  7   Rango_edad_De_14_a_17_Años                 2650 non-null   int64
#  8   Rango_edad_De_18_a_28_Años                 2650 non-null   int64
#  9   Rango_edad_De_29_a_50_Años                 2650 non-null   int64
# ...

# %%
# Se borraron las columnas Rango_edad_desconocido, Autenticación_Correo, ,Autenticación_Facebook,Autenticación_Googleplus,Autenticación_Linkedin,Autenticación_Twitter, Género_desconocido
df_segmentacion.drop(columns=["Género_desconocido"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Se borraron las columnas Rango_edad_desconocido, Autenticación_Correo, ,Autenticación_Facebook,Autenticación_Googleplus,Autenticación_Linkedin,Autenticación_Twitter, Género_desconocido
# ----> 2 df_segmentacion.drop(columns=["Género_desconocido"], inplace=True)
#
# File c:\Users\violeta\Documents\GitHub\MedcityHackathon\.venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# ...

# %%
df_segmentacion.head()
# Out:
#                                   Sedes  Rango_edad_De_14_a_17_Años  \
# 0         Aeroparque Juan Pablo Segundo                         183
# 1  Ampliación 1 Estación Caribe (Norte)                         137
# 2    Ampliación 2 Estación Caribe (Sur)                         111
# 3           Ampliación Estación Estadio                         350
# 4                   Ampliación La Honda                         313
#
#    Rango_edad_De_18_a_28_Años  Rango_edad_De_29_a_50_Años  \
# 0                         924                         543
# 1                         884                         511
# 2                         669                         347
# 3                        2126                        1260
# 4                        1251                         474
#
#    Rango_edad_Mayor_de_50_Años  Rango_edad_Menor_de_13_Años  \
# 0                           53                           10
# 1                           36                           11
# ...

# %%
# Exportar el DataFrame limpio y reemplzarlo en el mismo archivo csv
df_segmentacion.to_csv(r"C:\Users\violeta\Documents\GitHub\MedcityHackathon\Database\segmentacion_de_usuarios.csv", index=False, encoding="utf-8", sep =",")
